# %% [markdown]
# # Calculate steel stress, based on its tempereature and strain.
# ## Click "RUN" in every input cell.
#
# ![obraz.png](attachment:obraz.png)

# %%
# %run mat_prop_students_functions.ipynb

# %% [markdown]
# ## Show a chart for selected temperature
# ### Set the desired temperature in the cell below:

# %%
display(temp_plot_widget)

# Create button
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20Events.html#Example
button3 = ipywidgets.Button(description="Click Me!")
output3 = ipywidgets.Output()
display(button3, output3)

def on_button3_clicked(b):
    with output3:
        print("Button clicked.")
        single_plot(temp_plot_widget.value)

button3.on_click(on_button3_clicked)

# %% [markdown]
# ## Calculate stress in steel for a given temperature and strain
# ### Text input:

# %%
fy = 500  # (MPa)
temp = 200  # (°C)
ε = 0.001  # (-)
printing_steel = 'detailed'

sigma_steel(fy, temp, ε, printing_steel)

# %% [markdown]
# ### Interactive version:

# %%
display(fy_ipy)
display(temp_ipy)
display(eps_ipy)

# Create button
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20Events.html#Example
button2 = ipywidgets.Button(description="Click Me!")
output2 = ipywidgets.Output()
display(button2, output2)

def on_button2_clicked(b):
    with output2:
        print("Button clicked.")
        sigma_steel(fy_ipy.value, temp_ipy.value, eps_ipy.value, 'detailed')

button2.on_click(on_button2_clicked)
